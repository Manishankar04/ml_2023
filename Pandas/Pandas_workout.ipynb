# %%
#import the libraries
import pandas as pd

# %%
#import the dataset
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\Manishankar04\AppData\Local\Temp\ipykernel_14036\2312081839.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = [e/10 for e in car_sales["Price"]]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   40000.0
# 1   Honda    Red          87899      4   50000.0
# 2  Toyota   Blue          32549      3   70000.0
# 3     BMW  Black          11179      5  220000.0
# 4  Nissan  White         213095      4   35000.0
# 5  Toyota  Green          99213      4   45000.0
# 6   Honda   Blue          45698      4   75000.0
# 7   Honda   Blue          54738      4   70000.0
# 8  Toyota  White          60000      4   62500.0
# 9  Nissan  White          31600      4   97000.0

# %%
car_sales_missing= pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Doors"].mean()
# Out:
# 4.0

# %%
car_sales_missing["Doors"].fillna(car_sales_missing["Doors"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    4.0      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   40000.0
# 1   Honda    Red          87899      4   50000.0
# 2  Toyota   Blue          32549      3   70000.0
# 3     BMW  Black          11179      5  220000.0
# 4  Nissan  White         213095      4   35000.0
# 5  Toyota  Green          99213      4   45000.0
# 6   Honda   Blue          45698      4   75000.0
# 7   Honda   Blue          54738      4   70000.0
# 8  Toyota  White          60000      4   62500.0
# 9  Nissan  White          31600      4   97000.0

# %%
seats_column =  pd.Series([5,5,5,5,5])
car_sales["Sales"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales
# 0  Toyota  White         150043      4   40000.0    5.0
# 1   Honda    Red          87899      4   50000.0    5.0
# 2  Toyota   Blue          32549      3   70000.0    5.0
# 3     BMW  Black          11179      5  220000.0    5.0
# 4  Nissan  White         213095      4   35000.0    5.0
# 5  Toyota  Green          99213      4   45000.0    NaN
# 6   Honda   Blue          45698      4   75000.0    NaN
# 7   Honda   Blue          54738      4   70000.0    NaN
# 8  Toyota  White          60000      4   62500.0    NaN
# 9  Nissan  White          31600      4   97000.0    NaN

# %%
car_sales["Sales"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales
# 0  Toyota  White         150043      4   40000.0    5.0
# 1   Honda    Red          87899      4   50000.0    5.0
# 2  Toyota   Blue          32549      3   70000.0    5.0
# 3     BMW  Black          11179      5  220000.0    5.0
# 4  Nissan  White         213095      4   35000.0    5.0
# 5  Toyota  Green          99213      4   45000.0    5.0
# 6   Honda   Blue          45698      4   75000.0    5.0
# 7   Honda   Blue          54738      4   70000.0    5.0
# 8  Toyota  White          60000      4   62500.0    5.0
# 9  Nissan  White          31600      4   97000.0    5.0

# %%
fuel_economy = [8.25,4.65,7.85,9.05,7.65,6.55,8.45,5.75,4.50,8.25]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
#
#    Total Fuel Used
# 0       12378.5475
# 1        4087.3035
# 2        2555.0965
# 3        1011.6995
# 4       16301.7675
# 5        6498.4515
# 6        3861.4810
# 7        3147.4350
# 8        2700.0000
# 9        2607.0000

# %%
car_sales["Number of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
#
#    Total Fuel Used  Number of Wheels
# 0       12378.5475                 4
# 1        4087.3035                 4
# 2        2555.0965                 4
# 3        1011.6995                 4
# 4       16301.7675                 4
# 5        6498.4515                 4
# 6        3861.4810                 4
# 7        3147.4350                 4
# 8        2700.0000                 4
# 9        2607.0000                 4

# %%
car_sales["Passed Safety Test"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                 float64
# Sales                 float64
# Fuel per 100KM        float64
# Total Fuel Used       float64
# Number of Wheels        int64
# Passed Safety Test       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
#
#    Total Fuel Used  Number of Wheels  Passed Safety Test
# 0       12378.5475                 4                True
# 1        4087.3035                 4                True
# 2        2555.0965                 4                True
# 3        1011.6995                 4                True
# 4       16301.7675                 4                True
# 5        6498.4515                 4                True
# 6        3861.4810                 4                True
# 7        3147.4350                 4                True
# 8        2700.0000                 4                True
# 9        2607.0000                 4                True

# %%
car_sales = car_sales.drop("Total Fuel Used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
#
#    Number of Wheels  Passed Safety Test
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
#
#    Number of Wheels  Passed Safety Test
# 9                 4                True
# 0                 4                True
# 7                 4                True
# 6                 4                True
# 2                 4                True
# 4                 4                True
# 5                 4                True
# 3                 4                True
# 8                 4                True
# 1                 4                True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Sales  Fuel per 100KM  \
# 0  Toyota  White         150043      4   40000.0    5.0            8.25
# 1   Honda    Red          87899      4   50000.0    5.0            4.65
# 2  Toyota   Blue          32549      3   70000.0    5.0            7.85
# 3     BMW  Black          11179      5  220000.0    5.0            9.05
# 4  Nissan  White         213095      4   35000.0    5.0            7.65
# 5  Toyota  Green          99213      4   45000.0    5.0            6.55
# 6   Honda   Blue          45698      4   75000.0    5.0            8.45
# 7   Honda   Blue          54738      4   70000.0    5.0            5.75
# 8  Toyota  White          60000      4   62500.0    5.0            4.50
# 9  Nissan  White          31600      4   97000.0    5.0            8.25
#
#    Number of Wheels  Passed Safety Test
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True
